# %%
import torch
import os
import h5py
import pandas as pd
import numpy as np
import shutil
from sklearn.model_selection import train_test_split
from utils.PathDataset import Pathology_Dataset_test
from torch.utils.data import Dataset, DataLoader
from utils.T1Dataset import T1Dataset_regression_mr_path_test
from models.SENet import Model_path_mr
from lifelines.utils import concordance_index
from models.MLP import MLP
import torch
import torchtuples as tt
from utils.img_processing import convert_path,normalize_min_max
from pycox.datasets import metabric
from pycox.models import CoxPH
from pycox.evaluation import EvalSurv
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('G:\glioma\\final_data\glioma_survive\\5hmc\huashan_5hmc_.csv')
df
# Out:
#              patient  score_gene     score  IDH  WHO   Age  Gender  \
# 0       Pan_Jing_Wei    0.457889  0.186934    0    4  36.0       1
# 1           Geng_Xin    0.469941  0.318546    1    4  28.0       0
# 2       Wu_Jing_Zhen    0.460363  0.820950    1    3  60.0       0
# 3            Xin_Wen    0.797674  0.225211    0    2  33.0       0
# 4      Zhang_Guo_Wei    0.641296  0.252710    1    2  30.0       1
# 5        Qin_Mei_Hua    0.449362  0.091404    0    2  30.0       1
# 6      Ling_Yan_Rong    0.496287  0.199656    0    4  51.0       1
# 7     Zhuang_Zi_Ming    0.616854  0.369815    1    2  32.0       1
# 8       Huang_Xue_Yu    0.285971  0.320955    0    4  49.0       0
# 9       Shen_Lin_Jia    0.113935  0.299568    0    4  72.0       0
# 10     Chen_Zhen_Xin    0.255729  0.486150    0    4  66.0       1
# 11        Wu_Guo_Hua    0.244860  0.293034    0    4  35.0       1
# 12  Wang_Liang_Liang    0.739202  0.487270    1    4  32.0       0
# 13      Wu_Yong_Feng    0.340359  1.000000    0    4  39.0       1
# 14        Li_Mei_Hua    0.522146  0.780222    1    4  52.0       0
# 15     Shao_Dong_Fei    0.451450  0.004081    1    4  39.0       1
# 16     Song_Qi_Sheng    0.821017  0.148754    1    2  35.0       1
# 17     Bao_Sheng_Hai    0.523621  0.785719    0    4  50.0       1
# 18    Zheng_Wen_Ming    0.215128  0.235933    1    3  46.0       1
# 19     Jiang_Hui_Xun    0.445601  0.603052    0    4  51.0       1
# 20      Liu_Xiao_Tao    0.862764  0.526352    0    4  39.0       1
# 21           Li_Zong    0.546116  0.365500    1    3  41.0       1
# 22       Ma_Ling_Hua    0.390404  0.073410    1    2  39.0       0
# 23      Zhang_Wen_Li    0.673931  0.445802    1    2  34.0       1
# 24     Zhang_Xia_Wei    0.446988  0.232496    1    3  26.0       0
# 25      Lin_Hui_Xian    0.843046  0.396494    0    2  33.0       0
# 26   Wang_Ding_Qiong    0.359129  0.649824    1    2  43.0       0
# 27     Liu_Yang_Yang    0.512229  0.331879    0    4  28.0       1
# 28         Huang_Xin    0.286262  0.858599    0    4  25.0       1
# 37           29.27            1
# 38           10.93            1
# 39           59.20            0
# 40           58.83            0
# 41            5.17            1
# 42           13.87            0
# 43            5.53            1
# 44           17.53            1
# 45           58.00            0
# 46           18.53            1
# 47           57.90            0
# 48           22.33            1
# 49           21.00            1
# 50           11.40            1
# 51           38.73            1
# 52           20.37            1
# 53           29.10            1
# 54           15.50            1
# 55           26.33            1
# 56           27.10            1

# %%
df.head(1)
# Out:
#         patient  score_gene     score  IDH  WHO   Age  Gender  survival_month  \
# 0  Pan_Jing_Wei    0.457889  0.186934    0    4  36.0       1           27.13
#
#    status_dead
# 0            1

# %%
df_train_, df_test, y_train, y_test = train_test_split(df,df['patient'],test_size=0.2,random_state=201)
df_train, df_val, y_train, y_test = train_test_split(df_train_,df_train_['patient'],test_size=0.2,random_state=2018)
df_train_[['WHO','Age','Gender','IDH','score']] = df_train_[['WHO','Age','Gender','IDH','score']].astype('float32')
get_target = lambda df_train_: (df_train_['survival_month'].values, df_train_['status_dead'].values)
y_train = get_target(df_train_)
train_feature = df_train_[['WHO','Age','Gender','IDH','score']].values

df_test[['WHO','Age','Gender','IDH','score']] = df_test[['WHO','Age','Gender','IDH','score']].astype('float32')
val_feature = df_test[['WHO','Age','Gender','IDH','score']].values
get_target = lambda df_test: (df_test['survival_month'].values, df_test['status_dead'].values)
y_val = get_target(df_test)
val = tt.tuplefy(val_feature, y_val)

def calculate_param(df_TCGA_loc_M, model_cph1):
    df_TCGA_loc_M[['WHO','Age','Gender','IDH','score']] = df_TCGA_loc_M[['WHO','Age','Gender','IDH','score']].astype('float32')
    feature_TCGA_loc_M = df_TCGA_loc_M[['WHO','Age','Gender','IDH','score']].values
    get_target = lambda df_TCGA_loc_M: (df_TCGA_loc_M['survival_month'].values, df_TCGA_loc_M['status_dead'].values)
    durations_test_ex, events_test_ex = get_target(df_TCGA_loc_M)
    _ = model_cph1.compute_baseline_hazards()
    surv = model_cph1.predict_surv_df(feature_TCGA_loc_M)
    ev = EvalSurv(surv, durations_test_ex, events_test_ex, censor_surv='km')
    time_grid = np.linspace(durations_test_ex.min(), durations_test_ex.max(), 100)
    return ev.concordance_td(),ev.integrated_brier_score(time_grid)

# %%
in_features = train_feature.shape[1]
num_nodes = [32, 32]
out_features = 1
batch_norm = True
dropout = 0.1
output_bias = False

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm,
                              dropout, output_bias=output_bias)
model_cph = CoxPH(net, tt.optim.Adam)
batch_size = 10
lrfinder = model_cph.lr_finder(train_feature, y_train, batch_size, tolerance=10)
# _ = lrfinder.plot()
model_cph.optimizer.set_lr(lrfinder.get_best_lr())
epochs = 30
callbacks = [tt.callbacks.EarlyStopping()]
verbose = True
log = model_cph.fit(train_feature, y_train, batch_size, epochs, callbacks, verbose,
                val_data=val, val_batch_size=batch_size)
_ = log.plot()
# Out:
# 0:	[0s / 0s],		train_loss: 2.0940,	val_loss: 1.7733
# 1:	[0s / 0s],		train_loss: 2.0004,	val_loss: 1.4713
# 2:	[0s / 0s],		train_loss: 1.8432,	val_loss: 1.5531
# 3:	[0s / 0s],		train_loss: 1.7867,	val_loss: 1.2725
# 4:	[0s / 0s],		train_loss: 1.6162,	val_loss: 1.1906
# 5:	[0s / 0s],		train_loss: 1.6908,	val_loss: 1.1547
# 6:	[0s / 0s],		train_loss: 1.6080,	val_loss: 1.1315
# 7:	[0s / 0s],		train_loss: 1.5675,	val_loss: 1.1182
# 8:	[0s / 0s],		train_loss: 1.4865,	val_loss: 1.1770
# 9:	[0s / 0s],		train_loss: 1.7327,	val_loss: 1.1538
# 10:	[0s / 0s],		train_loss: 1.6000,	val_loss: 1.1890
# 11:	[0s / 0s],		train_loss: 1.4672,	val_loss: 1.1728
# 12:	[0s / 0s],		train_loss: 1.6102,	val_loss: 1.1194
# 13:	[0s / 0s],		train_loss: 1.6624,	val_loss: 1.0887
# 14:	[0s / 0s],		train_loss: 1.6497,	val_loss: 1.1027
# 15:	[0s / 0s],		train_loss: 1.5962,	val_loss: 1.2224
# 16:	[0s / 0s],		train_loss: 1.5468,	val_loss: 1.2288
# 17:	[0s / 0s],		train_loss: 1.7094,	val_loss: 1.2519
# 18:	[0s / 0s],		train_loss: 1.6978,	val_loss: 1.1569
# 19:	[0s / 0s],		train_loss: 1.4246,	val_loss: 1.1004
# 20:	[0s / 0s],		train_loss: 1.3752,	val_loss: 1.0851
# 21:	[0s / 0s],		train_loss: 1.7066,	val_loss: 1.1457
# 22:	[0s / 0s],		train_loss: 1.5380,	val_loss: 1.1509
# 23:	[0s / 0s],		train_loss: 1.5629,	val_loss: 1.1659
# 24:	[0s / 0s],		train_loss: 1.7458,	val_loss: 1.0781
# 25:	[0s / 0s],		train_loss: 1.5419,	val_loss: 1.0286
# 26:	[0s / 0s],		train_loss: 1.4756,	val_loss: 1.0207
# 27:	[0s / 0s],		train_loss: 1.4956,	val_loss: 1.0747
# 28:	[0s / 0s],		train_loss: 1.5623,	val_loss: 1.1341
# 29:	[0s / 0s],		train_loss: 1.4487,	val_loss: 1.1580

# %%
print("MM-CoxPH Mutil-Modal-A")
print("Huashan-Test-Set (c-index, brier scores)",calculate_param(df_test,model_cph))
# Out:
# MM-CoxPH Mutil-Modal-A
# Huashan-Test-Set (c-index, brier scores) (0.7254901960784313, 0.1686185257258582)

# %%
model_cph.save_net(os.path.join('G:\glioma\\final_data\glioma_survive\\5hmc\pth','MM-CoxPH Mutil-Modal-A.pth'))
